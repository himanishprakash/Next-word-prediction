# %%
import tensorflow as tf
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
data_text  = pd.read_csv('/content/df_commentary_new.csv')

# %%
data_text.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data_text = data_text.head(1000)

# %%
data_text.shape
# Out:
# (1000, 1)

# %%
tokenizer = Tokenizer()

tokenizer.fit_on_texts(data_text['Modified_Commentary'])

# %%
len(tokenizer.word_index)
# Out:
# 3582

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'it': 3,
#  'a': 4,
#  'to': 5,
#  'batsman': 6,
#  'on': 7,
#  'of': 8,
#  'off': 9,
#  'in': 10,
#  'four': 11,
#  'his': 12,
#  'bowler': 13,
#  'ball': 14,
#  'for': 15,
#  'he': 16,
#  'over': 17,
#  'was': 18,
#  'out': 19,
#  'is': 20,
#  'that': 21,
#  'from': 22,
#  'this': 23,
#  'with': 24,
#  'up': 25,
#  'back': 26,
#  'at': 27,
#  'short': 28,
#  'leg': 29,
#  'length': 30,
#  'six': 31,
#  'down': 32,
#  'away': 33,
#  'but': 34,
#  'by': 35,
#  'long': 36,
#  'b': 37,
#  'mid': 38,
#  'has': 39,
#  'into': 40,
#  'wicket': 41,
#  'delivery': 42,
#  'gets': 43,
#  'outside': 44,
#  'full': 45,
#  'as': 46,
#  'just': 47,
#  'one': 48,
#  '1': 49,
#  'run': 50,
#  'shot': 51,
#  'caught': 52,
#  'bat': 53,
#  '4s': 54,
#  'him': 55,
#  'through': 56,
#  'team': 57,
#  'no': 58,
#  'wide': 59,
#  'man': 60,
#  'c': 61,
#  'cover': 62,
#  'square': 63,
#  'edge': 64,
#  'all': 65,
#  'deep': 66,
#  'right': 67,
#  'fence': 68,
#  'not': 69,
#  'point': 70,
#  'get': 71,
#  'side': 72,
#  'way': 73,
#  'have': 74,
#  'good': 75,
#  'goes': 76,
#  'fine': 77,
#  'well': 78,
#  'had': 79,
#  "that's": 80,
#  'across': 81,
#  'went': 82,
#  'straight': 83,
#  'time': 84,
#  'inside': 85,
#  'pull': 86,
#  "he's": 87,
#  '6s': 88,
#  'an': 89,
#  'there': 90,
#  'runs': 91,
#  'third': 92,
#  'been': 93,
#  'boundary': 94,
#  'line': 95,
#  '2': 96,
#  'past': 97,
#  'fielder': 98,
#  'first': 99,
#  'takes': 100,
#  'too': 101,
#  'front': 102,
#  'middle': 103,
#  'stumps': 104,
#  'extra': 105,
#  'another': 106,
#  'bowled': 107,
#  'hit': 108,
#  '3': 109,
#  'slower': 110,
#  'end': 111,
#  'stump': 112,
#  'pace': 113,
#  'got': 114,
#  'enough': 115,
#  'forward': 116,
#  'some': 117,
#  'catch': 118,
#  'be': 119,
#  'behind': 120,
#  'top': 121,
#  'now': 122,
#  'backward': 123,
#  'go': 124,
#  'ground': 125,
#  'drive': 126,
#  'toss': 127,
#  'so': 128,
#  'what': 129,
#  'bounce': 130,
#  'does': 131,
#  'half': 132,
#  'again': 133,
#  'high': 134,
#  "it's": 135,
#  'towards': 136,
#  'low': 137,
#  "doesn't": 138,
#  'two': 139,
#  'flat': 140,
#  'pads': 141,
#  'here': 142,
#  'onto': 143,
#  'makes': 144,
#  'hands': 145,
#  'width': 146,
#  'chance': 147,
#  'going': 148,
#  "didn't": 149,
#  'rana': 150,
#  'more': 151,
#  'under': 152,
#  'ropes': 153,
#  'room': 154,
#  'around': 155,
#  'foot': 156,
#  'who': 157,
#  '5': 158,
#  'pitch': 159,
#  'crease': 160,
#  'lbw': 161,
#  'cut': 162,
#  'bit': 163,
#  'air': 164,
#  'after': 165,
#  'which': 166,
#  'early': 167,
#  'do': 168,
#  'big': 169,
#  'are': 170,
#  'yorker': 171,
#  'you': 172,
#  'stands': 173,
#  'face': 174,
#  'smith': 175,
#  'mccullum': 176,
#  'hard': 177,
#  'hand': 178,
#  'timing': 179,
#  'gone': 180,
#  'umpire': 181,
#  'left': 182,
#  'looking': 183,
#  '4': 184,
#  'much': 185,
#  'morris': 186,
#  'like': 187,
#  'head': 188,
#  'those': 189,
#  'would': 190,
#  'pulls': 191,
#  'maximum': 192,
#  'gap': 193,
#  'did': 194,
#  'rashid': 195,
#  "bowler's": 196,
#  'getting': 197,
#  'almost': 198,
#  'even': 199,
#  'once': 200,
#  'second': 201,
#  'slog': 202,
#  'then': 203,
#  'wrong': 204,
#  'done': 205,
#  'bowling': 206,
#  'comes': 207,
#  'running': 208,
#  'very': 209,
#  'misses': 210,
#  'between': 211,
#  'beats': 212,
#  "can't": 213,
#  "batsman's": 214,
#  'take': 215,
#  'himself': 216,
#  'lovely': 217,
#  'start': 218,
#  'slip': 219,
#  'will': 220,
#  'crowd': 221,
#  'poor': 222,
#  'keeper': 223,
#  'pandya': 224,
#  'still': 225,
#  'swing': 226,
#  'ipl': 227,
#  'quick': 228,
#  'easy': 229,
#  'picked': 230,
#  'quite': 231,
#  'uses': 232,
#  'coming': 233,
#  'region': 234,
#  'looks': 235,
#  'track': 236,
#  'flies': 237,
#  'really': 238,
#  'might': 239,
#  'its': 240,
#  'need': 241,
#  'ends': 242,
#  'game': 243,
#  'sends': 244,
#  'power': 245,
#  'hits': 246,
#  'before': 247,
#  'thick': 248,
#  'came': 249,
#  'diving': 250,
#  'fifty': 251,
#  'oh': 252,
#  'kedar': 253,
#  'innings': 254,
#  'played': 255,
#  'dropped': 256,
#  'keep': 257,
#  'reach': 258,
#  '0': 259,
#  'underneath': 260,
#  'nicely': 261,
#  'free': 262,
#  'arms': 263,
#  'dhawan': 264,
#  'bowls': 265,
#  '10': 266,
#  'only': 267,
#  'if': 268,
#  'leans': 269,
#  'put': 270,
#  'picks': 271,
#  'make': 272,
#  'sweep': 273,
#  'opens': 274,
#  'any': 275,
#  'where': 276,
#  'look': 277,
#  'today': 278,
#  'cracking': 279,
#  'come': 280,
#  'throw': 281,
#  'knee': 282,
#  'little': 283,
#  'close': 284,
#  'fires': 285,
#  'swings': 286,
#  'should': 287,
#  'pick': 288,
#  'perfection': 289,
#  '8': 290,
#  'fuller': 291,
#  'struck': 292,
#  'uthappa': 293,
#  'patel': 294,
#  'these': 295,
#  'single': 296,
#  'cutter': 297,
#  'than': 298,
#  'keeps': 299,
#  'made': 300,
#  'slices': 301,
#  '7': 302,
#  'volley': 303,
#  'offer': 304,
#  'walks': 305,
#  'lofts': 306,
#  'sticks': 307,
#  'missed': 308,
#  'ring': 309,
#  'rolls': 310,
#  'dhoni': 311,
#  'lifts': 312,
#  'pollard': 313,
#  'pandey': 314,
#  'slot': 315,
#  'call': 316,
#  'break': 317,
#  'can': 318,
#  '9': 319,
#  'wow': 320,
#  'morgan': 321,
#  'needed': 322,
#  'moment': 323,
#  'dive': 324,
#  'though': 325,
#  'drills': 326,
#  '17': 327,
#  'could': 328,
#  'trick': 329,
#  'throws': 330,
#  'both': 331,
#  'drives': 332,
#  'flick': 333,
#  'play': 334,
#  'finds': 335,
#  'flicks': 336,
#  'bhatia': 337,
#  'tossed': 338,
#  'touch': 339,
#  'whips': 340,
#  'cuts': 341,
#  'shortish': 342,
#  'beautifully': 343,
#  'form': 344,
#  'clears': 345,
#  'couple': 346,
#  'quickly': 347,
#  'waits': 348,
#  'took': 349,
#  'slightly': 350,
#  'toe': 351,
#  '6': 352,
#  'mind': 353,
#  'finger': 354,
#  'distance': 355,
#  'better': 356,
#  'skipper': 357,
#  'flying': 358,
#  'wrists': 359,
#  'banged': 360,
#  'races': 361,
#  'about': 362,
#  'hardik': 363,
#  'corner': 364,
#  'stand': 365,
#  'tiwary': 366,
#  'billings': 367,
#  'slow': 368,
#  '16': 369,
#  'strikes': 370,
#  'turn': 371,
#  'backs': 372,
#  'simple': 373,
#  'mills': 374,
#  'warner': 375,
#  'direct': 376,
#  'rope': 377,
#  "wasn't": 378,
#  '27': 379,
#  'against': 380,
#  '14': 381,
#  'swivels': 382,
#  'helps': 383,
#  'knock': 384,
#  'pad': 385,
#  'yadav': 386,
#  'cow': 387,
#  'hitting': 388,
#  'lynn': 389,
#  'moves': 390,
#  'parthiv': 391,
#  'boundaries': 392,
#  'pretty': 393,
#  'jadhav': 394,
#  '22': 395,
#  'completely': 396,
#  'being': 397,
#  "won't": 398,
#  "isn't": 399,
#  'when': 400,
#  'continues': 401,
#  'nothing': 402,
#  'tries': 403,
#  'three': 404,
#  'dives': 405,
#  'sits': 406,
#  'open': 407,
#  'far': 408,
#  'pune': 409,
#  'wanted': 410,
#  'ease': 411,
#  'mohit': 412,
#  'umesh': 413,
#  'thakur': 414,
#  'iyer': 415,
#  'bounces': 416,
#  'puts': 417,
#  'never': 418,
#  'looked': 419,
#  'best': 420,
#  'field': 421,
#  'sweeper': 422,
#  '24': 423,
#  'stays': 424,
#  'tall': 425,
#  'brings': 426,
#  'change': 427,
#  'target': 428,
#  'says': 429,
#  'trouble': 430,
#  'nails': 431,
#  'day': 432,
#  'few': 433,
#  '19': 434,
#  'balls': 435,
#  'kuldeep': 436,
#  'making': 437,
#  'wood': 438,
#  'sub': 439,
#  'pant': 440,
#  'reaches': 441,
#  'sat': 442,
#  'boy': 443,
#  'feet': 444,
#  'googly': 445,
#  'taken': 446,
#  'rocks': 447,
#  'ojha': 448,
#  'such': 449,
#  '11': 450,
#  'night': 451,
#  'playing': 452,
#  'clear': 453,
#  'quicker': 454,
#  "'un": 455,
#  'manages': 456,
#  'thumps': 457,
#  'lost': 458,
#  'set': 459,
#  'without': 460,
#  'height': 461,
#  'kept': 462,
#  'move': 463,
#  'non': 464,
#  'soft': 465,
#  'send': 466,
#  'impact': 467,
#  'tosses': 468,
#  'their': 469,
#  'kulkarni': 470,
#  'bottom': 471,
#  '50': 472,
#  'sees': 473,
#  'arc': 474,
#  'brilliant': 475,
#  'cummins': 476,
#  'plays': 477,
#  'flatter': 478,
#  'backing': 479,
#  'wickets': 480,
#  'anderson': 481,
#  'them': 482,
#  'leading': 483,
#  'control': 484,
#  'round': 485,
#  'bones': 486,
#  'cleared': 487,
#  'loft': 488,
#  'turns': 489,
#  'gives': 490,
#  'flighted': 491,
#  'lands': 492,
#  'streaky': 493,
#  'decides': 494,
#  'massive': 495,
#  '28': 496,
#  'mayank': 497,
#  'tried': 498,
#  'overs': 499,
#  'last': 500,
#  'fails': 501,
#  'edged': 502,
#  'rohit': 503,
#  'drops': 504,
#  'gg': 505,
#  '25': 506,
#  'having': 507,
#  'or': 508,
#  '18': 509,
#  'fingers': 510,
#  "couldn't": 511,
#  'ab': 512,
#  'de': 513,
#  'chase': 514,
#  'batting': 515,
#  'pressure': 516,
#  'smashes': 517,
#  'managed': 518,
#  'hold': 519,
#  'raced': 520,
#  'batsmen': 521,
#  'charge': 522,
#  'while': 523,
#  'mandeep': 524,
#  'infield': 525,
#  'crouches': 526,
#  'yet': 527,
#  'sink': 528,
#  'seam': 529,
#  'stop': 530,
#  'clips': 531,
#  'bother': 532,
#  'inches': 533,
#  'row': 534,
#  'real': 535,
#  '15': 536,
#  'timed': 537,
#  'lofted': 538,
#  'shows': 539,
#  'mark': 540,
#  "don't": 541,
#  'elevation': 542,
#  'nice': 543,
#  'fetch': 544,
#  'samson': 545,
#  'yuvi': 546,
#  'knuckle': 547,
#  'gave': 548,
#  'beat': 549,
#  'spot': 550,
#  'cutting': 551,
#  'absolutely': 552,
#  'huge': 553,
#  'especially': 554,
#  'taking': 555,
#  'plants': 556,
#  'mistake': 557,
#  'sent': 558,
#  'result': 559,
#  'zone': 560,
#  'gayle': 561,
#  'most': 562,
#  'mess': 563,
#  'wants': 564,
#  'work': 565,
#  'giving': 566,
#  'covers': 567,
#  'slaps': 568,
#  'smokes': 569,
#  'shuffles': 570,
#  'found': 571,
#  'eyes': 572,
#  'base': 573,
#  'southee': 574,
#  'other': 575,
#  'rest': 576,
#  'strike': 577,
#  'i': 578,
#  'suryakumar': 579,
#  'smacks': 580,
#  'punches': 581,
#  'they': 582,
#  'season': 583,
#  '13': 584,
#  'shots': 585,
#  'keeping': 586,
#  'body': 587,
#  'cheeky': 588,
#  'moved': 589,
#  'holds': 590,
#  'pitched': 591,
#  'beaten': 592,
#  'tye': 593,
#  'placed': 594,
#  'late': 595,
#  'smart': 596,
#  '30': 597,
#  'henriques': 598,
#  "there's": 599,
#  'naman': 600,
#  'hat': 601,
#  'give': 602,
#  'whipped': 603,
#  'allows': 604,
#  '21': 605,
#  'superb': 606,
#  'sailing': 607,
#  'safe': 608,
#  'how': 609,
#  'want': 610,
#  'always': 611,
#  'spin': 612,
#  'help': 613,
#  'chris': 614,
#  'tickle': 615,
#  'cannot': 616,
#  'believe': 617,
#  'position': 618,
#  'struggling': 619,
#  'home': 620,
#  'turning': 621,
#  'expensive': 622,
#  '12': 623,
#  'soon': 624,
#  'drop': 625,
#  'agarwal': 626,
#  'sixes': 627,
#  'batted': 628,
#  'miss': 629,
#  'buttler': 630,
#  'nitish': 631,
#  'we': 632,
#  'actually': 633,
#  'trying': 634,
#  'something': 635,
#  'krunal': 636,
#  'stunning': 637,
#  'pouches': 638,
#  'backed': 639,
#  'perhaps': 640,
#  'excellent': 641,
#  'bang': 642,
#  'bangs': 643,
#  'partnership': 644,
#  'wallops': 645,
#  'either': 646,
#  'effort': 647,
#  'worked': 648,
#  'collects': 649,
#  'straighter': 650,
#  'narine': 651,
#  'maxi': 652,
#  'sets': 653,
#  'dd': 654,
#  'gambhir': 655,
#  'grandhomme': 656,
#  'tad': 657,
#  'checked': 658,
#  'great': 659,
#  'find': 660,
#  'everything': 661,
#  'nailed': 662,
#  'maybe': 663,
#  '31': 664,
#  'mighty': 665,
#  'baby': 666,
#  'backwards': 667,
#  'finishes': 668,
#  'overpitched': 669,
#  'reverse': 670,
#  'perfect': 671,
#  'miles': 672,
#  'choudhary': 673,
#  'win': 674,
#  'swinging': 675,
#  'carves': 676,
#  'cramped': 677,
#  'ordinary': 678,
#  'punch': 679,
#  'sweeps': 680,
#  'skews': 681,
#  'slides': 682,
#  'sitter': 683,
#  'momentum': 684,
#  'process': 685,
#  'kitchen': 686,
#  'finish': 687,
#  'easily': 688,
#  'beating': 689,
#  'thought': 690,
#  'drifting': 691,
#  'dived': 692,
#  'previous': 693,
#  'things': 694,
#  'smack': 695,
#  'fast': 696,
#  'willow': 697,
#  'angle': 698,
#  "striker's": 699,
#  'class': 700,
#  'swipes': 701,
#  'muscles': 702,
#  'cricket': 703,
#  'rolled': 704,
#  'walk': 705,
#  'read': 706,
#  'stayed': 707,
#  'abd': 708,
#  'pathan': 709,
#  'fat': 710,
#  'followed': 711,
#  'chips': 712,
#  'next': 713,
#  'roy': 714,
#  'stokes': 715,
#  'park': 716,
#  'legs': 717,
#  'slashes': 718,
#  'part': 719,
#  'heave': 720,
#  'maxwell': 721,
#  '26': 722,
#  'bangalore': 723,
#  'lobs': 724,
#  'placement': 725,
#  'surely': 726,
#  'plenty': 727,
#  'pushed': 728,
#  'special': 729,
#  'errs': 730,
#  'faint': 731,
#  'khan': 732,
#  'called': 733,
#  'lions': 734,
#  'attempt': 735,
#  'blow': 736,
#  'stuff': 737,
#  'connection': 738,
#  'saha': 739,
#  'blockhole': 740,
#  'nair': 741,
#  'woakes': 742,
#  'kohli': 743,
#  'ankit': 744,
#  'eoin': 745,
#  'dispatched': 746,
#  'alright': 747,
#  'dangerous': 748,
#  'match': 749,
#  'yuvraj': 750,
#  'hop': 751,
#  'fair': 752,
#  'given': 753,
#  'may': 754,
#  'slash': 755,
#  'despite': 756,
#  'sky': 757,
#  'settles': 758,
#  'shorter': 759,
#  'already': 760,
#  'gift': 761,
#  'miscues': 762,
#  '32': 763,
#  'pulled': 764,
#  'vacant': 765,
#  'times': 766,
#  '45': 767,
#  'combo': 768,
#  'friendly': 769,
#  'partner': 770,
#  'style': 771,
#  'upwards': 772,
#  '37': 773,
#  'leaps': 774,
#  'yorkers': 775,
#  'fours': 776,
#  'shimmies': 777,
#  'watches': 778,
#  'glove': 779,
#  'accepts': 780,
#  'lets': 781,
#  'bends': 782,
#  'tough': 783,
#  'credit': 784,
#  'vain': 785,
#  'sure': 786,
#  'react': 787,
#  'floated': 788,
#  'stay': 789,
#  'muscle': 790,
#  'arm': 791,
#  'decision': 792,
#  'attempted': 793,
#  'steers': 794,
#  'striker': 795,
#  'many': 796,
#  'karthik': 797,
#  'along': 798,
#  'were': 799,
#  'check': 800,
#  'waited': 801,
#  'raina': 802,
#  'falls': 803,
#  'held': 804,
#  'men': 805,
#  'saw': 806,
#  'themselves': 807,
#  'awful': 808,
#  'probably': 809,
#  'dk': 810,
#  '20': 811,
#  'bats': 812,
#  'jumps': 813,
#  'meat': 814,
#  'wings': 815,
#  'happy': 816,
#  'sinks': 817,
#  'tonks': 818,
#  'opportunity': 819,
#  'stage': 820,
#  'hander': 821,
#  'vohra': 822,
#  'days': 823,
#  'further': 824,
#  'bad': 825,
#  'opening': 826,
#  'wider': 827,
#  'finding': 828,
#  'bails': 829,
#  'hint': 830,
#  'ever': 831,
#  'vijay': 832,
#  'shankar': 833,
#  'captain': 834,
#  'gujarat': 835,
#  'mumbai': 836,
#  'breakthrough': 837,
#  'say': 838,
#  'effortlessly': 839,
#  'punjab': 840,
#  'angled': 841,
#  'your': 842,
#  'caresses': 843,
#  'sharma': 844,
#  'thampi': 845,
#  'kishan': 846,
#  'finch': 847,
#  'bhuvi': 848,
#  'pulling': 849,
#  'bipul': 850,
#  'gloves': 851,
#  'hoick': 852,
#  'chahal': 853,
#  'eye': 854,
#  'celebration': 855,
#  'follows': 856,
#  'dropping': 857,
#  'stride': 858,
#  'anything': 859,
#  'smashed': 860,
#  'old': 861,
#  'smacked': 862,
#  'palms': 863,
#  'helped': 864,
#  'showing': 865,
#  'aravind': 866,
#  'certainly': 867,
#  'neither': 868,
#  'slap': 869,
#  'tier': 870,
#  'standing': 871,
#  'act': 872,
#  'case': 873,
#  'spots': 874,
#  'effect': 875,
#  'holding': 876,
#  'mates': 877,
#  'shuffle': 878,
#  'response': 879,
#  'me': 880,
#  'motion': 881,
#  'final': 882,
#  'thank': 883,
#  'straightforward': 884,
#  'dolly': 885,
#  'tahir': 886,
#  'doing': 887,
#  'ms': 888,
#  '34': 889,
#  'job': 890,
#  'stood': 891,
#  'disdain': 892,
#  'same': 893,
#  'pitches': 894,
#  'launches': 895,
#  'scoops': 896,
#  "keeper's": 897,
#  'skids': 898,
#  'lot': 899,
#  'imran': 900,
#  'umpires': 901,
#  'new': 902,
#  'spell': 903,
#  'heaves': 904,
#  'drags': 905,
#  'flew': 906,
#  'rushes': 907,
#  'mistimed': 908,
#  'see': 909,
#  'dear': 910,
#  'complete': 911,
#  'seemed': 912,
#  'instead': 913,
#  'presents': 914,
#  'cleanly': 915,
#  'balloons': 916,
#  'landed': 917,
#  'fiercely': 918,
#  'survives': 919,
#  'pole': 920,
#  'spotted': 921,
#  'ran': 922,
#  'cracks': 923,
#  'sightscreen': 924,
#  'delight': 925,
#  'deliver': 926,
#  'advances': 927,
#  'crashes': 928,
#  'slashed': 929,
#  'flash': 930,
#  'strong': 931,
#  'learning': 932,
#  'byes': 933,
#  'collect': 934,
#  'packing': 935,
#  'often': 936,
#  'axar': 937,
#  'ploy': 938,
#  'sandeep': 939,
#  'scoop': 940,
#  'used': 941,
#  'sped': 942,
#  'sneaks': 943,
#  'dips': 944,
#  'beautiful': 945,
#  'presses': 946,
#  'stanlake': 947,
#  'flight': 948,
#  'stopped': 949,
#  'breaks': 950,
#  'knees': 951,
#  'fired': 952,
#  'vinod': 953,
#  'nadeem': 954,
#  'piece': 955,
#  'connects': 956,
#  'finally': 957,
#  "would've": 958,
#  'kumar': 959,
#  'hut': 960,
#  'safely': 961,
#  'lap': 962,
#  'bites': 963,
#  'pk': 964,
#  'anywhere': 965,
#  'touched': 966,
#  'spun': 967,
#  'idea': 968,
#  'moving': 969,
#  'perishes': 970,
#  'rishi': 971,
#  'welcome': 972,
#  'tickles': 973,
#  'leaping': 974,
#  'fielding': 975,
#  'fullish': 976,
#  'outfield': 977,
#  'skips': 978,
#  'karun': 979,
#  'possible': 980,
#  'zak': 981,
#  'darted': 982,
#  'ravi': 983,
#  'throat': 984,
#  '39': 985,
#  'miller': 986,
#  'spanks': 987,
#  'chahar': 988,
#  'jadeja': 989,
#  'zaheer': 990,
#  'middled': 991,
#  'completed': 992,
#  'nowhere': 993,
#  'my': 994,
#  'pay': 995,
#  'nerves': 996,
#  'seems': 997,
#  'lobbed': 998,
#  'proper': 999,
#  'causing': 1000,
#  ...}

# %%
data_text['Modified_Commentary']
# Out:
# 0      FOUR, first boundary for batsman and team. Ful...
# 1      FOUR, back-to-back boundaries to end the first...
# 2      FOUR, hit straight back at bowler and he was l...
# 3      FOUR, another full toss, it's Jadhav this time...
# 4      FOUR, four more. Jadhav starting to really fin...
#                              ...
# 995    out Caught by Uthappa!! Umesh Yadav strikes an...
# 996    FOUR, that's harsh on the bowler. That didn't ...
# 997    FOUR, welcome to Delhi says Iyer. Shortish and...
# 998    out Caught by Billings!! Zak attack strikes. T...
# 999    FOUR, that's a gift and batsman accepts it gle...
# Name: Modified_Commentary, Length: 1000, dtype: object

# %%
max_length = data_text['Modified_Commentary'].str.len().max()
max_length
# Out:
# 798

# %%
max_text_index = data_text[data_text['Modified_Commentary'].str.len() == max_length].index[0]
max_text_index
# Out:
# 325

# %%
for i in range(len(data_text['Modified_Commentary'])):
    text = data_text['Modified_Commentary'][i]

# %%
input_sequences = []
for i in range(len(data_text['Modified_Commentary'])):
    text = data_text['Modified_Commentary'][i]
    token_list = tokenizer.texts_to_sequences([text])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
input_sequences
# Out:
# [[11, 99],
#  [11, 99, 94],
#  [11, 99, 94, 15],
#  [11, 99, 94, 15, 6],
#  [11, 99, 94, 15, 6, 2],
#  [11, 99, 94, 15, 6, 2, 57],
#  [11, 99, 94, 15, 6, 2, 57, 45],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141, 322],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141, 322, 5],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141, 322, 5, 119],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141, 322, 5, 119, 270],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141, 322, 5, 119, 270, 33],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141, 322, 5, 119, 270, 33, 2],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141, 322, 5, 119, 270, 33, 2, 6],
#  [11, 99, 94, 15, 6, 2, 57, 45, 2, 7, 1, 141, 322, 5, 119, 270, 33, 2, 6, 194],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38,
#   41],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38,
#   41,
#   346],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38,
#   41,
#   346,
#   8],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38,
#   41,
#   346,
#   8,
#   416],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38,
#   41,
#   346,
#   8,
#   416,
#   2],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38,
#   41,
#   346,
#   8,
#   416,
#   2,
#   40],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38,
#   41,
#   346,
#   8,
#   416,
#   2,
#   40,
#   1],
#  [11,
#   99,
#   94,
#   15,
#   6,
#   2,
#   57,
#   45,
#   2,
#   7,
#   1,
#   141,
#   322,
#   5,
#   119,
#   270,
#   33,
#   2,
#   6,
#   194,
#   47,
#   21,
#   230,
#   3,
#   25,
#   2,
#   746,
#   3,
#   17,
#   38,
#   41,
#   346,
#   8,
#   416,
#   2,
#   40,
#   1,
#   68],
#  [11, 26],
#  [11, 26, 5],
#  [11, 26, 5, 26],
#  [11, 26, 5, 26, 392],
#  [11, 26, 5, 26, 392, 5],
#  [11, 26, 5, 26, 392, 5, 111],
#  [11, 26, 5, 26, 392, 5, 111, 1],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133, 13],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133, 13, 20],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133, 13, 20, 4],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133, 13, 20, 4, 657],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133, 13, 20, 4, 657, 28],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133, 13, 20, 4, 657, 28, 10],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133, 13, 20, 4, 657, 28, 10, 12],
#  [11, 26, 5, 26, 392, 5, 111, 1, 99, 17, 133, 13, 20, 4, 657, 28, 10, 12, 30],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27,
#   92],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27,
#   92,
#   60],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27,
#   92,
#   60,
#   548],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27,
#   92,
#   60,
#   548,
#   25],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27,
#   92,
#   60,
#   548,
#   25,
#   1],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27,
#   92,
#   60,
#   548,
#   25,
#   1,
#   514],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27,
#   92,
#   60,
#   548,
#   25,
#   1,
#   514,
#   393],
#  [11,
#   26,
#   5,
#   26,
#   392,
#   5,
#   111,
#   1,
#   99,
#   17,
#   133,
#   13,
#   20,
#   4,
#   657,
#   28,
#   10,
#   12,
#   30,
#   6,
#   79,
#   1,
#   146,
#   5,
#   162,
#   2,
#   16,
#   149,
#   2031,
#   5,
#   108,
#   3,
#   177,
#   47,
#   594,
#   3,
#   120,
#   70,
#   2,
#   848,
#   27,
#   92,
#   60,
#   548,
#   25,
#   1,
#   514,
#   393,
#   347],
#  [11, 108],
#  [11, 108, 83],
#  [11, 108, 83, 26],
#  [11, 108, 83, 26, 27],
#  [11, 108, 83, 26, 27, 13],
#  [11, 108, 83, 26, 27, 13, 2],
#  [11, 108, 83, 26, 27, 13, 2, 16],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5, 71],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5, 71, 12],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5, 71, 12, 178],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5, 71, 12, 178, 25],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5, 71, 12, 178, 25, 200],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5, 71, 12, 178, 25, 200, 151],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5, 71, 12, 178, 25, 200, 151, 1],
#  [11, 108, 83, 26, 27, 13, 2, 16, 18, 595, 5, 71, 12, 178, 25, 200, 151, 1, 9],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991,
#   3],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991,
#   3,
#   747],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991,
#   3,
#   747,
#   5],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991,
#   3,
#   747,
#   5,
#   549],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991,
#   3,
#   747,
#   5,
#   549,
#   1],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991,
#   3,
#   747,
#   5,
#   549,
#   1,
#   38],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991,
#   3,
#   747,
#   5,
#   549,
#   1,
#   38,
#   9],
#  [11,
#   108,
#   83,
#   26,
#   27,
#   13,
#   2,
#   16,
#   18,
#   595,
#   5,
#   71,
#   12,
#   178,
#   25,
#   200,
#   151,
#   1,
#   9,
#   297,
#   166,
#   198,
#   1172,
#   394,
#   157,
#   2032,
#   32,
#   2,
#   658,
#   12,
#   126,
#   991,
#   3,
#   747,
#   5,
#   549,
#   1,
#   38,
#   9,
#   98],
#  [11, 106],
#  [11, 106, 45],
#  [11, 106, 45, 127],
#  [11, 106, 45, 127, 135],
#  [11, 106, 45, 127, 135, 394],
#  [11, 106, 45, 127, 135, 394, 23],
#  [11, 106, 45, 127, 135, 394, 23, 84],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16, 271],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16, 271, 12],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16, 271, 12, 550],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16, 271, 12, 550, 40],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16, 271, 12, 550, 40, 1],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16, 271, 12, 550, 40, 1, 66],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16, 271, 12, 550, 40, 1, 66, 38],
#  [11, 106, 45, 127, 135, 394, 23, 84, 2, 16, 271, 12, 550, 40, 1, 66, 38, 41],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13,
#   87],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13,
#   87,
#   1484],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13,
#   87,
#   1484,
#   1],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13,
#   87,
#   1484,
#   1,
#   171],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13,
#   87,
#   1484,
#   1,
#   171,
#   35],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13,
#   87,
#   1484,
#   1,
#   171,
#   35,
#   231],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13,
#   87,
#   1484,
#   1,
#   171,
#   35,
#   231,
#   4],
#  [11,
#   106,
#   45,
#   127,
#   135,
#   394,
#   23,
#   84,
#   2,
#   16,
#   271,
#   12,
#   550,
#   40,
#   1,
#   66,
#   38,
#   41,
#   68,
#   69,
#   659,
#   206,
#   22,
#   13,
#   87,
#   1484,
#   1,
#   171,
#   35,
#   231,
#   4,
#   163],
#  [11, 11],
#  [11, 11, 151],
#  [11, 11, 151, 394],
#  [11, 11, 151, 394, 1485],
#  [11, 11, 151, 394, 1485, 5],
#  [11, 11, 151, 394, 1485, 5, 238],
#  [11, 11, 151, 394, 1485, 5, 238, 660],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12, 179],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12, 179, 122],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12, 179, 122, 2],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12, 179, 122, 2, 87],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12, 179, 122, 2, 87, 183],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12, 179, 122, 2, 87, 183, 748],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12, 179, 122, 2, 87, 183, 748, 23],
#  [11, 11, 151, 394, 1485, 5, 238, 660, 12, 179, 122, 2, 87, 183, 748, 23, 20],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247,
#   849],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247,
#   849,
#   3],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247,
#   849,
#   3,
#   17],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247,
#   849,
#   3,
#   17,
#   1],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247,
#   849,
#   3,
#   17,
#   1,
#   98],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247,
#   849,
#   3,
#   17,
#   1,
#   98,
#   13],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247,
#   849,
#   3,
#   17,
#   1,
#   98,
#   13,
#   152],
#  [11,
#   11,
#   151,
#   394,
#   1485,
#   5,
#   238,
#   660,
#   12,
#   179,
#   122,
#   2,
#   87,
#   183,
#   748,
#   23,
#   20,
#   596,
#   515,
#   1486,
#   298,
#   47,
#   2033,
#   12,
#   53,
#   27,
#   661,
#   16,
#   1173,
#   21,
#   77,
#   29,
#   20,
#   25,
#   2,
#   128,
#   16,
#   348,
#   15,
#   1,
#   26,
#   8,
#   4,
#   30,
#   42,
#   5,
#   280,
#   5,
#   55,
#   247,
#   849,
#   3,
#   17,
#   1,
#   98,
#   13,
#   152,
#   516],
#  [19, 6],
#  [19, 6, 50],
#  [19, 6, 50, 19],
#  [19, 6, 50, 19, 49],
#  [19, 6, 50, 19, 49, 50],
#  [19, 6, 50, 19, 49, 50, 992],
#  [19, 6, 50, 19, 49, 50, 992, 551],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034, 4],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034, 4, 41],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034, 4, 41, 19],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034, 4, 41, 19, 8],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034, 4, 41, 19, 8, 993],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034, 4, 41, 19, 8, 993, 80],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034, 4, 41, 19, 8, 993, 80, 4],
#  [19, 6, 50, 19, 49, 50, 992, 551, 39, 2034, 4, 41, 19, 8, 993, 80, 4, 1174],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30,
#   14],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30,
#   14,
#   44],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30,
#   14,
#   44,
#   9],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30,
#   14,
#   44,
#   9,
#   394],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30,
#   14,
#   44,
#   9,
#   394,
#   442],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30,
#   14,
#   44,
#   9,
#   394,
#   442,
#   7],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30,
#   14,
#   44,
#   9,
#   394,
#   442,
#   7,
#   12],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
#   23,
#   51,
#   166,
#   16,
#   255,
#   18,
#   2036,
#   3,
#   18,
#   4,
#   30,
#   14,
#   44,
#   9,
#   394,
#   442,
#   7,
#   12,
#   26],
#  [19,
#   6,
#   50,
#   19,
#   49,
#   50,
#   992,
#   551,
#   39,
#   2034,
#   4,
#   41,
#   19,
#   8,
#   993,
#   80,
#   4,
#   1174,
#   281,
#   22,
#   1,
#   66,
#   994,
#   1487,
#   87,
#   552,
#   662,
#   1,
#   112,
#   22,
#   36,
#   29,
#   2,
#   394,
#   20,
#   19,
#   8,
#   142,
#   23,
#   20,
#   4,
#   553,
#   323,
#   10,
#   1,
#   2035,
#   8,
#   1,
#   749,
#   554,
#   46,
#   394,
#   18,
#   183,
#   128,
#   75,
#   199,
# ...
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6,
#   61],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6,
#   61,
#   375],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6,
#   61,
#   375,
#   37],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6,
#   61,
#   375,
#   37,
#   13],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6,
#   61,
#   375,
#   37,
#   13,
#   352],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6,
#   61,
#   375,
#   37,
#   13,
#   352,
#   109],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6,
#   61,
#   375,
#   37,
#   13,
#   352,
#   109,
#   88],
#  [19,
#   52,
#   35,
#   375,
#   75,
#   1506,
#   80,
#   114,
#   164,
#   672,
#   7,
#   3,
#   73,
#   25,
#   40,
#   1,
#   451,
#   757,
#   375,
#   758,
#   152,
#   3,
#   27,
#   36,
#   7,
#   2,
#   100,
#   3,
#   13,
#   79,
#   1507,
#   1,
#   113,
#   32,
#   7,
#   1,
#   42,
#   1000,
#   374,
#   5,
#   124,
#   56,
#   24,
#   1,
#   852,
#   101,
#   167,
#   67,
#   9,
#   1,
#   351,
#   111,
#   8,
#   1,
#   53,
#   6,
#   61,
#   375,
#   37,
#   13,
#   352,
#   109,
#   88,
#   49],
#  [31, 99],
#  [31, 99, 14],
#  [31, 99, 14, 673],
#  [31, 99, 14, 673, 1508],
#  [31, 99, 14, 673, 1508, 10],
#  [31, 99, 14, 673, 1508, 10, 1],
#  [31, 99, 14, 673, 1508, 10, 1, 227],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517, 3],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517, 3, 17],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517, 3, 17, 36],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517, 3, 17, 36, 29],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517, 3, 17, 36, 29, 4],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517, 3, 17, 36, 29, 4, 28],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517, 3, 17, 36, 29, 4, 28, 14],
#  [31, 99, 14, 673, 1508, 10, 1, 227, 16, 517, 3, 17, 36, 29, 4, 28, 14, 22],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40,
#   89],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40,
#   89,
#   2055],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40,
#   89,
#   2055,
#   86],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40,
#   89,
#   2055,
#   86,
#   2],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40,
#   89,
#   2055,
#   86,
#   2,
#   43],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40,
#   89,
#   2055,
#   86,
#   2,
#   43,
#   115],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40,
#   89,
#   2055,
#   86,
#   2,
#   43,
#   115,
#   7],
#  [31,
#   99,
#   14,
#   673,
#   1508,
#   10,
#   1,
#   227,
#   16,
#   517,
#   3,
#   17,
#   36,
#   29,
#   4,
#   28,
#   14,
#   22,
#   13,
#   673,
#   286,
#   40,
#   89,
#   2055,
#   86,
#   2,
#   43,
#   115,
#   7,
#   3],
#  [19, 853],
#  [19, 853, 50],
#  [19, 853, 50, 19],
#  [19, 853, 50, 19, 376],
#  [19, 853, 50, 19, 376, 108],
#  [19, 853, 50, 19, 376, 108, 2],
#  [19, 853, 50, 19, 376, 108, 2, 80],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57, 24],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57, 24, 4],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57, 24, 4, 2056],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57, 24, 4, 2056, 674],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57, 24, 4, 2056, 674, 10],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57, 24, 4, 2056, 674, 10, 1],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57, 24, 4, 2056, 674, 10, 1, 227],
#  [19, 853, 50, 19, 376, 108, 2, 80, 3, 57, 24, 4, 2056, 674, 10, 1, 227, 266],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119,
#   558],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119,
#   558,
#   26],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119,
#   558,
#   26,
#   2],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119,
#   558,
#   26,
#   2,
#   16],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119,
#   558,
#   26,
#   2,
#   16,
#   79],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119,
#   558,
#   26,
#   2,
#   16,
#   79,
#   753],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119,
#   558,
#   26,
#   2,
#   16,
#   79,
#   753,
#   25],
#  [19,
#   853,
#   50,
#   19,
#   376,
#   108,
#   2,
#   80,
#   3,
#   57,
#   24,
#   4,
#   2056,
#   674,
#   10,
#   1,
#   227,
#   266,
#   1183,
#   106,
#   86,
#   51,
#   22,
#   673,
#   23,
#   2057,
#   83,
#   5,
#   38,
#   41,
#   853,
#   207,
#   208,
#   32,
#   267,
#   5,
#   119,
#   558,
#   26,
#   2,
#   16,
#   79,
#   753,
#   25,
#   1509],
#  ...]

# %%
max_len = max(len(x) for x in input_sequences)

# %%
max_len
# Out:
# 153

# %%
padded_input_sequences = pad_sequences(input_sequences, maxlen=max_len + 1, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[   0,    0,    0, ...,    0,   11,   99],
#        [   0,    0,    0, ...,   11,   99,   94],
#        [   0,    0,    0, ...,   99,   94,   15],
#        ...,
#        [   0,    0,    0, ..., 1472,   33,    5],
#        [   0,    0,    0, ...,   33,    5,    1],
#        [   0,    0,    0, ...,    5,    1,   68]], dtype=int32)

# %%
x = padded_input_sequences[:, :-1]
y = padded_input_sequences[:, -1]

# %%
x
# Out:
# array([[   0,    0,    0, ...,    0,    0,   11],
#        [   0,    0,    0, ...,    0,   11,   99],
#        [   0,    0,    0, ...,   11,   99,   94],
#        ...,
#        [   0,    0,    0, ...,    7, 1472,   33],
#        [   0,    0,    0, ..., 1472,   33,    5],
#        [   0,    0,    0, ...,   33,    5,    1]], dtype=int32)

# %%
x.shape
# Out:
# (45086, 153)

# %%
y.shape
# Out:
# (45086,)

# %%
y = to_categorical(y, num_classes=len(tokenizer.word_index)+1)
y.shape
# Out:
# (45086, 3583)

# %%
max_len
# Out:
# 153

# %%
len(tokenizer.word_index)+1
# Out:
# 3583

# %%
model = Sequential()
model.add(Embedding(input_dim=3583, output_dim= 100, input_length=max_len))
model.add(LSTM(100, return_sequences=True)) # Pass return_sequences to LSTM
model.add(LSTM(100))
model.add(Dense(3583, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 153, 100)          358300
#
#  lstm (LSTM)                 (None, 153, 100)          80400
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 3583)              361883
#
# =================================================================
# Total params: 880983 (3.36 MB)
# Trainable params: 880983 (3.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x,y,epochs=5)
# Out:
# Epoch 1/5
# 1409/1409 [==============================] - 23s 16ms/step - loss: 0.5683 - accuracy: 0.8742
# Epoch 2/5
# 1409/1409 [==============================] - 23s 16ms/step - loss: 0.5535 - accuracy: 0.8775
# Epoch 3/5
# 1409/1409 [==============================] - 23s 16ms/step - loss: 0.5463 - accuracy: 0.8786
# Epoch 4/5
# 1409/1409 [==============================] - 22s 16ms/step - loss: 0.5333 - accuracy: 0.8827
# Epoch 5/5
# 1409/1409 [==============================] - 22s 16ms/step - loss: 0.5250 - accuracy: 0.8841

# %%
import numpy as np

# %%
eval_data = data_text.iloc[-5:]

# %%
eval_sequences = tokenizer.texts_to_sequences(eval_data['Modified_Commentary'])
eval_padded = pad_sequences(eval_sequences, maxlen=max_len + 1, padding='pre')

x_eval = eval_padded[:, :-1]
y_eval = eval_padded[:, -1]
y_eval = to_categorical(y_eval, num_classes=len(tokenizer.word_index)+1)

# Evaluate the model
results = model.evaluate(x_eval, y_eval, verbose=0)
print(f"Evaluation results on the last 5 sentences: {results}")

# Calculate accuracy on the last 5 sentences
accuracy = results[1]  # The second element in results corresponds to accuracy
print(f"Accuracy on the last 5 sentences: {accuracy}")

# Make predictions on the last 5 sentences
predictions = model.predict(x_eval)
print(f"Predictions on the last 5 sentences: {predictions}")
# Out:
# Evaluation results on the last 5 sentences: [1.7894920110702515, 0.800000011920929]
# Accuracy on the last 5 sentences: 0.800000011920929
# 1/1 [==============================] - 0s 22ms/step
# Predictions on the last 5 sentences: [[3.44079820e-10 1.62860047e-07 1.62230339e-04 ... 1.84178484e-19
#   1.89934687e-23 1.51066620e-18]
#  [1.09123731e-10 9.86378118e-02 1.18839294e-02 ... 9.03979142e-15
#   1.08133854e-16 7.54801126e-24]
#  [1.61696299e-11 3.31455492e-03 7.95396772e-06 ... 4.58756362e-29
#   5.84464416e-28 1.44562878e-30]
#  [9.79486825e-10 7.08068819e-06 6.23552070e-04 ... 1.25802220e-16
#   1.04563302e-18 5.93197908e-13]
#  [3.29034924e-11 2.60880665e-06 2.28099510e-04 ... 6.29555376e-25
#   2.60511155e-29 2.71005054e-25]]

# %% [markdown]
# ### with 60 percent accuracy

# %%
# Separate into x_eval and y_eval
x_eval = eval_padded[:, :-1]
y_eval = eval_padded[:, -1]
y_eval = to_categorical(y_eval, num_classes=len(tokenizer.word_index)+1)

# Evaluate the model
results = model.evaluate(x_eval, y_eval, verbose=0)
print(f"Evaluation results on the last 5 sentences: {results}")

# Make predictions on the last 5 sentences
predictions = model.predict(x_eval)
predicted_indices = np.argmax(predictions, axis=1)

# Function to convert sequences back to words
def sequences_to_texts(tokenizer, sequences):
    reverse_word_index = dict((i, word) for word, i in tokenizer.word_index.items())
    texts = []
    for sequence in sequences:
        words = [reverse_word_index.get(i, '?') for i in sequence]
        texts.append(' '.join(words))
    return texts

# Convert original and predicted sequences to texts
original_texts = sequences_to_texts(tokenizer, eval_sequences)
predicted_texts = sequences_to_texts(tokenizer, predicted_indices.reshape(-1, 1))

# Print each of the words from the original and predicted sequences
for i in range(len(original_texts)):
    print(f"Original sentence {i+1}: {original_texts[i]}")
    print(f"Predicted next word for sentence {i+1}: {predicted_texts[i]}")
    print()
# Out:
# Evaluation results on the last 5 sentences: [1.7894920110702515, 0.800000011920929]
# 1/1 [==============================] - 0s 32ms/step
# Original sentence 1: out caught by uthappa umesh yadav strikes and removes the big fish he bowled much better compared to his first spell and earns himself a wicket it was a pacy test match line and length short of a good length delivery on fourth fifth stump line batsman gets a faint outside tickle looking to run it down towards third man settles into the safe mitts of uthappa batsman c uthappa b bowler 39 25 4s 7
# Predicted next word for sentence 1: 7
#
# Original sentence 2: four that's harsh on the bowler that didn't deserve to go to the boundary it was banged in short and bowler bent his back there iyer is surprised by the pace and bounce on that delivery he jumps and just sticks his bat out hoping that it doesn't hit him the ball flies past the keeper off his shoulder and dribbles away into the third man fence the umpire thinks it came off the bat and gives four runs
# Predicted next word for sentence 2: the
#
# Original sentence 3: four welcome to delhi says iyer shortish and wide outside off iyer treks back and fiercely cuts it behind square on the off side gets it well out of the reach of backward point
# Predicted next word for sentence 3: point
#
# Original sentence 4: out caught by billings zak attack strikes trap set and trap sprung so batsman's promotion fails lasted for just two balls it was a fuller length delivery on off stump line batsman went for a half hearted flick it appeared that the ball might have stopped on the wicket nonetheless he was early into the shot and it was the slower ball from bowler that fooled the batsman there skies it towards deep square leg billings sprawls in forward and pouches it with ease bowler roars in delight batsman c billings b bowler 1 2
# Predicted next word for sentence 4: 2
#
# Original sentence 5: four that's a gift and batsman accepts it gleefully half volley on off stump batsman takes it from there and flicks it fiercely past mid on rockets away to the fence
# Predicted next word for sentence 5: fence

# %%
eval_sequences = tokenizer.texts_to_sequences(eval_data['Modified_Commentary'])
max_predict_len = 10

# Function to predict the next n words
def predict_next_n_words(model, tokenizer, seed_text, n_words):
    result = []
    for _ in range(n_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len, padding='pre')
        predicted_probs = model.predict(token_list, verbose=0)
        predicted_index = np.argmax(predicted_probs, axis=1)[0]
        predicted_word = tokenizer.index_word[predicted_index]
        result.append(predicted_word)
        seed_text += ' ' + predicted_word
    return result

# Evaluate the model
reverse_word_index = dict((i, word) for word, i in tokenizer.word_index.items())
for i, seq in enumerate(eval_sequences):
    if len(seq) > 10:
        first_10_words = seq[:10]
    else:
        first_10_words = seq

    first_10_words_text = ' '.join(reverse_word_index.get(word, '?') for word in first_10_words)
    predicted_words = predict_next_n_words(model, tokenizer, first_10_words_text, max_predict_len)
    actual_next_10_words = seq[10:20] if len(seq) > 20 else seq[10:]
    actual_next_10_words_text = ' '.join(reverse_word_index.get(word, '?') for word in actual_next_10_words)

    print(f"Sentence {i+1}:")
    print(f"First 10 words: {first_10_words_text}")
    print(f"Actual next 10 words: {actual_next_10_words_text}")
    print(f"Predicted next 10 words: {' '.join(predicted_words)}")
    print()
# Out:
# Sentence 1:
# First 10 words: out caught by uthappa umesh yadav strikes and removes the
# Actual next 10 words: big fish he bowled much better compared to his first
# Predicted next 10 words: big fish he walks down intercepts the length and bowls
#
# Sentence 2:
# First 10 words: four that's harsh on the bowler that didn't deserve to
# Actual next 10 words: go to the boundary it was banged in short and
# Predicted next 10 words: wait for batsman he enticingly tosses this short ball on
#
# Sentence 3:
# First 10 words: four welcome to delhi says iyer shortish and wide outside
# Actual next 10 words: off iyer treks back and fiercely cuts it behind square
# Predicted next 10 words: off batsman throws his arms to clobber it fine the
#
# Sentence 4:
# First 10 words: out caught by billings zak attack strikes trap set and
# Actual next 10 words: trap sprung so batsman's promotion fails lasted for just two
# Predicted next 10 words: trap sprung so batsman's promotion fails lasted for any a
#
# Sentence 5:
# First 10 words: four that's a gift and batsman accepts it gleefully half
# Actual next 10 words: volley on off stump batsman takes it from there and
# Predicted next 10 words: volley on off stump batsman brings him for a pull

# %% [markdown]
# ## with the accuracy of 90 percent

# %%
eval_sequences = tokenizer.texts_to_sequences(eval_data['Modified_Commentary'])
eval_padded = pad_sequences(eval_sequences, maxlen=max_len + 1, padding='pre')

x_eval = eval_padded[:, :-1]
y_eval = eval_padded[:, -1]
y_eval = to_categorical(y_eval, num_classes=len(tokenizer.word_index)+1)

# Evaluate the model
results = model.evaluate(x_eval, y_eval, verbose=0)
print(f"Evaluation results on the last 5 sentences: {results}")

# Calculate accuracy on the last 5 sentences
accuracy = results[1]  # The second element in results corresponds to accuracy
print(f"Accuracy on the last 5 sentences: {accuracy}")

# Make predictions on the last 5 sentences
predictions = model.predict(x_eval)
print(f"Predictions on the last 5 sentences: {predictions}")
# Out:
# Evaluation results on the last 5 sentences: [0.5841593742370605, 0.6000000238418579]
# Accuracy on the last 5 sentences: 0.6000000238418579
# 1/1 [==============================] - 0s 21ms/step
# Predictions on the last 5 sentences: [[1.27901978e-09 1.63285485e-09 4.04725615e-05 ... 5.80933427e-21
#   7.31618691e-32 1.83667369e-24]
#  [1.07257024e-11 3.64310920e-01 3.51343118e-03 ... 1.75843360e-19
#   1.73291322e-22 2.42096062e-25]
#  [4.95682141e-12 3.58189136e-04 4.96491202e-06 ... 7.31024279e-34
#   1.07494313e-29 2.70576480e-25]
#  [2.65667922e-11 3.96799882e-09 9.38424182e-06 ... 3.38177567e-21
#   1.87199217e-24 9.27186955e-19]
#  [1.20213587e-11 5.20853048e-11 6.47364368e-06 ... 1.23431556e-26
#   5.44430417e-36 5.33603013e-28]]

# %%
eval_sequences = tokenizer.texts_to_sequences(eval_data['Modified_Commentary'])
max_predict_len = 10

# Function to predict the next n words
def predict_next_n_words(model, tokenizer, seed_text, n_words):
    result = []
    for _ in range(n_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len, padding='pre')
        predicted_probs = model.predict(token_list, verbose=0)
        predicted_index = np.argmax(predicted_probs, axis=1)[0]
        predicted_word = tokenizer.index_word[predicted_index]
        result.append(predicted_word)
        seed_text += ' ' + predicted_word
    return result

# Evaluate the model
reverse_word_index = dict((i, word) for word, i in tokenizer.word_index.items())
for i, seq in enumerate(eval_sequences):
    if len(seq) > 10:
        first_10_words = seq[:10]
    else:
        first_10_words = seq

    first_10_words_text = ' '.join(reverse_word_index.get(word, '?') for word in first_10_words)
    predicted_words = predict_next_n_words(model, tokenizer, first_10_words_text, max_predict_len)
    actual_next_10_words = seq[10:20] if len(seq) > 20 else seq[10:]
    actual_next_10_words_text = ' '.join(reverse_word_index.get(word, '?') for word in actual_next_10_words)

    print(f"Sentence {i+1}:")
    print(f"First 10 words: {first_10_words_text}")
    print(f"Actual next 10 words: {actual_next_10_words_text}")
    print(f"Predicted next 10 words: {' '.join(predicted_words)}")
    print()
# Out:
# Sentence 1:
# First 10 words: out caught by uthappa umesh yadav strikes and removes the
# Actual next 10 words: big fish he bowled much better compared to his first
# Predicted next 10 words: big fish he bowled much better compared to his first
#
# Sentence 2:
# First 10 words: four that's harsh on the bowler that didn't deserve to
# Actual next 10 words: go to the boundary it was banged in short and
# Predicted next 10 words: go to the boundary it was banged in short and
#
# Sentence 3:
# First 10 words: four welcome to delhi says iyer shortish and wide outside
# Actual next 10 words: off iyer treks back and fiercely cuts it behind square
# Predicted next 10 words: off iyer treks back and fiercely cuts it behind square
#
# Sentence 4:
# First 10 words: out caught by billings zak attack strikes trap set and
# Actual next 10 words: trap sprung so batsman's promotion fails lasted for just two
# Predicted next 10 words: trap sprung so batsman's promotion fails lasted for just two
#
# Sentence 5:
# First 10 words: four that's a gift and batsman accepts it gleefully half
# Actual next 10 words: volley on off stump batsman takes it from there and
# Predicted next 10 words: volley on off stump batsman takes it so a touch

# %%
eval_data_1 = data_text.iloc[-10:]

# %%
eval_sequences = tokenizer.texts_to_sequences(eval_data_1['Modified_Commentary'])
max_predict_len = 10

# Function to predict the next n words
def predict_next_n_words(model, tokenizer, seed_text, n_words):
    result = []
    for _ in range(n_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len, padding='pre')
        predicted_probs = model.predict(token_list, verbose=0)
        predicted_index = np.argmax(predicted_probs, axis=1)[0]
        predicted_word = tokenizer.index_word[predicted_index]
        result.append(predicted_word)
        seed_text += ' ' + predicted_word
    return result

# Evaluate the model
reverse_word_index = dict((i, word) for word, i in tokenizer.word_index.items())
for i, seq in enumerate(eval_sequences):
    if len(seq) > 10:
        first_10_words = seq[:10]
    else:
        first_10_words = seq

    first_10_words_text = ' '.join(reverse_word_index.get(word, '?') for word in first_10_words)
    predicted_words = predict_next_n_words(model, tokenizer, first_10_words_text, max_predict_len)
    actual_next_10_words = seq[10:20] if len(seq) > 20 else seq[10:]
    actual_next_10_words_text = ' '.join(reverse_word_index.get(word, '?') for word in actual_next_10_words)

    print(f"Sentence {i+1}:")
    print(f"First 10 words: {first_10_words_text}")
    print(f"Actual next 10 words: {actual_next_10_words_text}")
    print(f"Predicted next 10 words: {' '.join(predicted_words)}")
    print()
# Out:
# Sentence 1:
# First 10 words: four exquisite he's seeing the cricket ball like a football
# Actual next 10 words: all timing he is not trying to hit the leather
# Predicted next 10 words: all timing with a open length delivery it was a
#
# Sentence 2:
# First 10 words: four starts with a full toss on leg easy peasy
# Actual next 10 words: for batsman he clips it in front of square on
# Predicted next 10 words: for batsman he clips it in front of square on
#
# Sentence 3:
# First 10 words: 2 runs to long on 50 run stand in the
# Actual next 10 words: fifth over a gentle nudge into the leg side followed
# Predicted next 10 words: fifth over a gentle nudge into the leg side followed
#
# Sentence 4:
# First 10 words: out caught by uthappa the umpire took ages to raise
# Actual next 10 words: his finger perhaps it looked like he had a look
# Predicted next 10 words: his finger perhaps it looked like he had no one
#
# Sentence 5:
# First 10 words: four cheeky delicate and effective uses the slightest of width
# Actual next 10 words: on this short ball outside off and sends it wide
# Predicted next 10 words: on this short ball outside off and sends it wide
#
# Sentence 6:
# First 10 words: out caught by uthappa umesh yadav strikes and removes the
# Actual next 10 words: big fish he bowled much better compared to his first
# Predicted next 10 words: big fish he bowled much better compared to his first
#
# Sentence 7:
# First 10 words: four that's harsh on the bowler that didn't deserve to
# Actual next 10 words: go to the boundary it was banged in short and
# Predicted next 10 words: go to the boundary it was banged in short and
#
# Sentence 8:
# First 10 words: four welcome to delhi says iyer shortish and wide outside
# Actual next 10 words: off iyer treks back and fiercely cuts it behind square
# Predicted next 10 words: off iyer treks back and fiercely cuts it behind square
#
# Sentence 9:
# First 10 words: out caught by billings zak attack strikes trap set and
# Actual next 10 words: trap sprung so batsman's promotion fails lasted for just two
# Predicted next 10 words: trap sprung so batsman's promotion fails lasted for just two
#
# Sentence 10:
# First 10 words: four that's a gift and batsman accepts it gleefully half
# Actual next 10 words: volley on off stump batsman takes it from there and
# Predicted next 10 words: volley on off stump batsman takes it so a touch

# %%
import time
text = "batsman"

for i in range(20):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=130, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
